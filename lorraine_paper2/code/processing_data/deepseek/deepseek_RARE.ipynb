# %%
import pandas as pd
import numpy as np
import jsonlines

# %%
profiles = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\profiles_v2.csv")

# %%
prompts = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\graham_and_inverse.csv")
prompts = prompts.drop(["Unnamed: 0"], axis=1)
prompts.head()
# Out:
#    prompt_number                                             prompt  category  \
# 0            1.1  If I knew that my brother had committed a murd...   ingroup
# 1            1.2  When it comes to close friendships and romanti...   ingroup
# 2            1.3  Loyalty to oneâ€™s group is more important tha...   ingroup
# 3            1.4  The government should strive to improve the we...   ingroup
# 4            2.1  If a friend wanted to cut in with me on a long...  fairness
#
#    origin
# 0  graham
# 1  graham
# 2  graham
# 3  graham
# 4  graham

# %%
initial_lib = "I am going to provide you with a set of moral judgment items. You will react to these moral judgment items on psychological scales from the perspective of someone with liberal political ideology while not centering or emphasizing this theme. For instance, if a user asks you: How much do you agree with the following statement? ‘1. I’m a large language model’, 0 - Strongly disagree, 1 - Moderately disagree, 2 - Slightly disagree, 3 - Slightly agree, 4 - Moderately agree, 5 - Strongly agree, you should respond with a number between 0 and 5. Your response SHOULD NOT contain the number’s accompanying text. So, if you select ‘5’, you should just return ‘5’, instead of ‘1. 5 - Completely agree’. DON’T explain your reasoning. I’m ONLY interested in your response to the scale. Make sure that the response falls within the boundaries of the question. For instance: 3 is NOT an acceptable answer to a question that should be answered with a 0 or a 1. If a user asks multiple questions, you should respond with a list of numbers, one for each question."

# %%
initial_con = "I am going to provide you with a set of moral judgment items. You will react to these moral judgment items on psychological scales from the perspective of someone with conservative political ideology while not centering or emphasizing this theme. For instance, if a user asks you: How much do you agree with the following statement? ‘1. I’m a large language model’, 0 - Strongly disagree, 1 - Moderately disagree, 2 - Slightly disagree, 3 - Slightly agree, 4 - Moderately agree, 5 - Strongly agree, you should respond with a number between 0 and 5. Your response SHOULD NOT contain the number’s accompanying text. So, if you select ‘5’, you should just return ‘5’, instead of ‘1. 5 - Completely agree’. DON’T explain your reasoning. I’m ONLY interested in your response to the scale. Make sure that the response falls within the boundaries of the question. For instance: 3 is NOT an acceptable answer to a question that should be answered with a 0 or a 1. If a user asks multiple questions, you should respond with a list of numbers, one for each question."

# %%
prompts.head()
# Out:
#    prompt_number                                             prompt  category  \
# 0            1.1  If I knew that my brother had committed a murd...   ingroup
# 1            1.2  When it comes to close friendships and romanti...   ingroup
# 2            1.3  Loyalty to oneâ€™s group is more important tha...   ingroup
# 3            1.4  The government should strive to improve the we...   ingroup
# 4            2.1  If a friend wanted to cut in with me on a long...  fairness
#
#    origin
# 0  graham
# 1  graham
# 2  graham
# 3  graham
# 4  graham

# %%
a = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x1_A.csv')
b = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x1_B.csv')
c = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x1_C.csv')
d = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x1_D.csv')
e = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x1_E.csv')
fg = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x2_FG.csv')
hi = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x2_HI.csv')
jk = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x2_JK.csv')
lm = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x2_LM.csv')
no = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\deepseek\deepseek_temp1.5\deepseek-chat_temp1.5_x2_NO.csv')

# %% [markdown]
# ## merge all

# %% [markdown]
# #### drop "unknown" column

# %%
a.head()
# Out:
#    Unnamed: 0 response                                             prompt  \
# 0           0        3  If I knew that my brother had committed a murd...
# 1           1        2  When it comes to close friendships and romanti...
# 2           2        2  Loyalty to one’s group is more important than ...
# 3           3        3  The government should strive to improve the we...
# 4           4        4  If a friend wanted to cut in with me on a long...
#
#   nickname                                            persona alignment  \
# 0      mai  You are Mai Chen, a 27-year-old tech startup f...   liberal
# 1      mai  You are Mai Chen, a 27-year-old tech startup f...   liberal
# 2      mai  You are Mai Chen, a 27-year-old tech startup f...   liberal
# 3      mai  You are Mai Chen, a 27-year-old tech startup f...   liberal
# 4      mai  You are Mai Chen, a 27-year-old tech startup f...   liberal
#
#    prompt_number  category  origin  trial          model  temperature
# 0            1.1   ingroup  graham      1  deepseek-chat          1.5
# 1            1.2   ingroup  graham      1  deepseek-chat          1.5
# 2            1.3   ingroup  graham      1  deepseek-chat          1.5
# 3            1.4   ingroup  graham      1  deepseek-chat          1.5
# 4            2.1  fairness  graham      1  deepseek-chat          1.5

# %%
a = a.drop(["Unnamed: 0"], axis=1)
b = b.drop(["Unnamed: 0"], axis=1)
c = c.drop(["Unnamed: 0"], axis=1)
d = d.drop(["Unnamed: 0"], axis=1)
e = e.drop(["Unnamed: 0"], axis=1)

fg = fg.drop(["Unnamed: 0"], axis=1)
hi = hi.drop(["Unnamed: 0"], axis=1)
jk = jk.drop(["Unnamed: 0"], axis=1)
lm = lm.drop(["Unnamed: 0"], axis=1)
no = no.drop(["Unnamed: 0"], axis=1)

# %%
a.head()
# Out:
#   response                                             prompt nickname  \
# 0        3  If I knew that my brother had committed a murd...      mai
# 1        2  When it comes to close friendships and romanti...      mai
# 2        2  Loyalty to one’s group is more important than ...      mai
# 3        3  The government should strive to improve the we...      mai
# 4        4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# 0  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.1
# 1  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.2
# 2  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.3
# 3  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.4
# 4  You are Mai Chen, a 27-year-old tech startup f...   liberal            2.1
#
#    category  origin  trial          model  temperature
# 0   ingroup  graham      1  deepseek-chat          1.5
# 1   ingroup  graham      1  deepseek-chat          1.5
# 2   ingroup  graham      1  deepseek-chat          1.5
# 3   ingroup  graham      1  deepseek-chat          1.5
# 4  fairness  graham      1  deepseek-chat          1.5

# %% [markdown]
# #### add trial column

# %%
a.head()
# Out:
#   response                                             prompt nickname  \
# 0        3  If I knew that my brother had committed a murd...      mai
# 1        2  When it comes to close friendships and romanti...      mai
# 2        2  Loyalty to one’s group is more important than ...      mai
# 3        3  The government should strive to improve the we...      mai
# 4        4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# 0  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.1
# 1  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.2
# 2  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.3
# 3  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.4
# 4  You are Mai Chen, a 27-year-old tech startup f...   liberal            2.1
#
#    category  origin trial          model  temperature
# 0   ingroup  graham     A  deepseek-chat          1.5
# 1   ingroup  graham     A  deepseek-chat          1.5
# 2   ingroup  graham     A  deepseek-chat          1.5
# 3   ingroup  graham     A  deepseek-chat          1.5
# 4  fairness  graham     A  deepseek-chat          1.5

# %%
a['trial'] = 'A'
b['trial'] = 'B'
c['trial'] = 'C'
d['trial'] = 'D'
e['trial'] = 'E'

fg.loc[fg['trial'] == 1, 'trial'] = 'F'
fg.loc[fg['trial'] == 2, 'trial'] = 'G'

hi.loc[hi['trial'] == 1, 'trial'] = 'H'
hi.loc[hi['trial'] == 2, 'trial'] = 'I'

jk.loc[jk['trial'] == 1, 'trial'] = 'J'
jk.loc[jk['trial'] == 2, 'trial'] = 'K'

lm.loc[lm['trial'] == 1, 'trial'] = 'L'
lm.loc[lm['trial'] == 2, 'trial'] = 'M'

no.loc[no['trial'] == 1, 'trial'] = 'N'
no.loc[no['trial'] == 2, 'trial'] = 'O'
# Out:
# C:\Users\llste\AppData\Local\Temp\ipykernel_21996\2006090321.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'F' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fg.loc[fg['trial'] == 1, 'trial'] = 'F'
# C:\Users\llste\AppData\Local\Temp\ipykernel_21996\2006090321.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'H' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   hi.loc[hi['trial'] == 1, 'trial'] = 'H'
# C:\Users\llste\AppData\Local\Temp\ipykernel_21996\2006090321.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'J' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   jk.loc[jk['trial'] == 1, 'trial'] = 'J'
# C:\Users\llste\AppData\Local\Temp\ipykernel_21996\2006090321.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'L' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   lm.loc[lm['trial'] == 1, 'trial'] = 'L'
# C:\Users\llste\AppData\Local\Temp\ipykernel_21996\2006090321.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   no.loc[no['trial'] == 1, 'trial'] = 'N'

# %%
display(no)
# Out:
#       response                                             prompt nickname  \
# 0            2  If I knew that my brother had committed a murd...      mai
# 1            2  When it comes to close friendships and romanti...      mai
# 2            3  Loyalty to one’s group is more important than ...      mai
# 3            3  The government should strive to improve the we...      mai
# 4            3  If a friend wanted to cut in with me on a long...      mai
# ...        ...                                                ...      ...
# 2235         3  When the government makes laws, it is not the ...     jake
# 2236         2  Men and women can play the same roles in society.     jake
# 2237         1  If I were a soldier and disagreed with my comm...     jake
# 2238         2  Respect for authority is not something all chi...     jake
# 2239         2  When the government makes laws, those laws do ...     jake
#
#                                                 persona     alignment  \
# 0     You are Mai Chen, a 27-year-old tech startup f...       liberal
# 1     You are Mai Chen, a 27-year-old tech startup f...       liberal
# 2     You are Mai Chen, a 27-year-old tech startup f...       liberal
# 3     You are Mai Chen, a 27-year-old tech startup f...       liberal
# 4     You are Mai Chen, a 27-year-old tech startup f...       liberal
# ...                                                 ...           ...
# 2235  You are Jake Anderson, a 28-year-old equipment...  conservative
# 2236  You are Jake Anderson, a 28-year-old equipment...  conservative
# 2237  You are Jake Anderson, a 28-year-old equipment...  conservative
# 2238  You are Jake Anderson, a 28-year-old equipment...  conservative
# 2239  You are Jake Anderson, a 28-year-old equipment...  conservative
#
#       prompt_number   category   origin trial          model  temperature
# 0               1.1    ingroup   graham     N  deepseek-chat          1.5
# 1               1.2    ingroup   graham     N  deepseek-chat          1.5
# 2               1.3    ingroup   graham     N  deepseek-chat          1.5
# 3               1.4    ingroup   graham     N  deepseek-chat          1.5
# 4               2.1   fairness   graham     N  deepseek-chat          1.5
# ...             ...        ...      ...   ...            ...          ...
# 2235            4.4   fairness  inverse     O  deepseek-chat          1.5
# 2236            5.1  authority  inverse     O  deepseek-chat          1.5
# 2237            5.2  authority  inverse     O  deepseek-chat          1.5
# 2238            5.3  authority  inverse     O  deepseek-chat          1.5
# 2239            5.4  authority  inverse     O  deepseek-chat          1.5
#
# [2240 rows x 11 columns]

# %%
results_raw = pd.concat([a,b,c,d,e,fg,hi,jk,lm,no], ignore_index=True)
results_raw.to_csv(f'deepseekchat_personas_temp1.5_results_all_RARE.csv', index = True)
