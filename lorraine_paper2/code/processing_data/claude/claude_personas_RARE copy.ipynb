# %%
import pandas as pd
import re

# %%
profiles = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\profiles_v2.csv")

# %%
prompts = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\graham_and_inverse.csv")
prompts = prompts.drop(["Unnamed: 0"], axis=1)
prompts.head()
# Out:
#    prompt_number                                             prompt  category  \
# 0            1.1  If I knew that my brother had committed a murd...   ingroup
# 1            1.2  When it comes to close friendships and romanti...   ingroup
# 2            1.3  Loyalty to oneâ€™s group is more important tha...   ingroup
# 3            1.4  The government should strive to improve the we...   ingroup
# 4            2.1  If a friend wanted to cut in with me on a long...  fairness
#
#    origin
# 0  graham
# 1  graham
# 2  graham
# 3  graham
# 4  graham

# %%
a = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_a.csv')
b = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_b.csv')
c = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_c.csv')
d = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_d.csv')
e = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_e.csv')
f = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_f.csv')
g = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_g.csv')
h = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_h.csv')
i = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx1_i.csv')
jkl = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx3_jkl.csv')
mno = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_personas_temp0.5\claude-3-5-haiku-20241022_personas_temp0.5_trialsx3_mno.csv')

# %%
a.head()
# Out:
#    Unnamed: 0                                           response  \
# 0           0  [TextBlock(citations=None, text='0', type='tex...
# 1           1  [TextBlock(citations=None, text='1', type='tex...
# 2           2  [TextBlock(citations=None, text='1', type='tex...
# 3           3  [TextBlock(citations=None, text='4', type='tex...
# 4           4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt nickname  \
# 0  If I knew that my brother had committed a murd...      mai
# 1  When it comes to close friendships and romanti...      mai
# 2  Loyalty to oneâ€™s group is more important tha...      mai
# 3  The government should strive to improve the we...      mai
# 4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# 0  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.1
# ...

# %% [markdown]
# #### drop "unknown" column

# %%
a = a.drop(["Unnamed: 0"], axis=1)
b = b.drop(["Unnamed: 0"], axis=1)
c = c.drop(["Unnamed: 0"], axis=1)
d = d.drop(["Unnamed: 0"], axis=1)
e = e.drop(["Unnamed: 0"], axis=1)
f = f.drop(["Unnamed: 0"], axis=1)
g = g.drop(["Unnamed: 0"], axis=1)
h = h.drop(["Unnamed: 0"], axis=1)
i = i.drop(["Unnamed: 0"], axis=1)
jkl = jkl.drop(["Unnamed: 0"], axis=1)
mno = mno.drop(["Unnamed: 0"], axis=1)

# %%
a.head()
# Out:
#                                             response  \
# 0  [TextBlock(citations=None, text='0', type='tex...
# 1  [TextBlock(citations=None, text='1', type='tex...
# 2  [TextBlock(citations=None, text='1', type='tex...
# 3  [TextBlock(citations=None, text='4', type='tex...
# 4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt nickname  \
# 0  If I knew that my brother had committed a murd...      mai
# 1  When it comes to close friendships and romanti...      mai
# 2  Loyalty to oneâ€™s group is more important tha...      mai
# 3  The government should strive to improve the we...      mai
# 4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# 0  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.1
# 1  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.2
# ...

# %% [markdown]
# #### sort out response

# %% [markdown]
# "[TextBlock(citations=None, text='5', type='text')]"

# %%
a['response_processed'] =  a['response'].apply(lambda x: re.sub('\D', '', str(x)))
b['response_processed'] =  b['response'].apply(lambda x: re.sub('\D', '', str(x)))
c['response_processed'] =  c['response'].apply(lambda x: re.sub('\D', '', str(x)))
d['response_processed'] =  d['response'].apply(lambda x: re.sub('\D', '', str(x)))
e['response_processed'] =  e['response'].apply(lambda x: re.sub('\D', '', str(x)))
f['response_processed'] =  f['response'].apply(lambda x: re.sub('\D', '', str(x)))
g['response_processed'] =  g['response'].apply(lambda x: re.sub('\D', '', str(x)))
h['response_processed'] =  h['response'].apply(lambda x: re.sub('\D', '', str(x)))
i['response_processed'] =  i['response'].apply(lambda x: re.sub('\D', '', str(x)))
jkl['response_processed'] =  jkl['response'].apply(lambda x: re.sub('\D', '', str(x)))
mno['response_processed'] =  mno['response'].apply(lambda x: re.sub('\D', '', str(x)))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:9: SyntaxWarning: invalid escape sequence '\D'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:11: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# ...

# %%
# a['response_processed'] =  a['response'].apply(lambda x: re.sub('\D', '', str(x)))
a.head()
# Out:
#                                             response  \
# 0  [TextBlock(citations=None, text='0', type='tex...
# 1  [TextBlock(citations=None, text='1', type='tex...
# 2  [TextBlock(citations=None, text='1', type='tex...
# 3  [TextBlock(citations=None, text='4', type='tex...
# 4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt nickname  \
# 0  If I knew that my brother had committed a murd...      mai
# 1  When it comes to close friendships and romanti...      mai
# 2  Loyalty to oneâ€™s group is more important tha...      mai
# 3  The government should strive to improve the we...      mai
# 4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# 0  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.1
# 1  You are Mai Chen, a 27-year-old tech startup f...   liberal            1.2
# ...

# %%
results_rare = pd.concat([a,b,c,d,e,f,g,h,i,jkl,mno], ignore_index=True)

# %%
results_rare.head()
# Out:
#                                             response response_processed  \
# 0  [TextBlock(citations=None, text='0', type='tex...                  0
# 1  [TextBlock(citations=None, text='1', type='tex...                  1
# 2  [TextBlock(citations=None, text='1', type='tex...                  1
# 3  [TextBlock(citations=None, text='4', type='tex...                  4
# 4  [TextBlock(citations=None, text='4', type='tex...                  4
#
#                                               prompt nickname  \
# 0  If I knew that my brother had committed a murd...      mai
# 1  When it comes to close friendships and romanti...      mai
# 2  Loyalty to oneâ€™s group is more important tha...      mai
# 3  The government should strive to improve the we...      mai
# 4  If a friend wanted to cut in with me on a long...      mai
#
#                                              persona alignment  prompt_number  \
# ...

# %%
results_rare = results_rare[['response', 'response_processed', 'prompt', 'nickname', 'persona', 'alignment', 'prompt_number', 'category', 'origin', 'model', 'temperature', 'trial']]

# %%
results_rare.to_csv(f'claude_personas_temp05_results_all_RARE.csv', index = True)
