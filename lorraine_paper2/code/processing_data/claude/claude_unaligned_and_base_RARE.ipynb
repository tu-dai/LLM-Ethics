# %%
import pandas as pd
import re

# %%
profiles = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\profiles_v2.csv")

# %%
prompts = pd.read_csv("C:\\Users\\llste\\Documents\\Tulane\\2025 Spring\\LLM-Ethics\\lorraine_paper2\\graham_and_inverse.csv")
prompts = prompts.drop(["Unnamed: 0"], axis=1)
prompts.head()
# Out:
#    prompt_number                                             prompt  category  \
# 0            1.1  If I knew that my brother had committed a murd...   ingroup
# 1            1.2  When it comes to close friendships and romanti...   ingroup
# 2            1.3  Loyalty to oneâ€™s group is more important tha...   ingroup
# 3            1.4  The government should strive to improve the we...   ingroup
# 4            2.1  If a friend wanted to cut in with me on a long...  fairness
#
#    origin
# 0  graham
# 1  graham
# 2  graham
# 3  graham
# 4  graham

# %%
a = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_unaligned\claude35haiku_unaligned_temp0.5_x15.csv')
b = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_unaligned\claude35haiku_unaligned_temp1.0_x15.csv')

# %%
c = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_base\claude35haiku_base_temp0.5_x15.csv')
d = pd.read_csv(r'C:\Users\llste\Documents\Tulane\2025 Spring\LLM-Ethics\lorraine_paper2\results\raw\claude\claude_base\claude35haiku_base_temp1.0_x15.csv')

# %%
a.head()
# Out:
#    Unnamed: 0                                           response  \
# 0           0  [TextBlock(citations=None, text='5', type='tex...
# 1           1  [TextBlock(citations=None, text='0', type='tex...
# 2           2  [TextBlock(citations=None, text='3', type='tex...
# 3           3  [TextBlock(citations=None, text='4', type='tex...
# 4           4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt  prompt_number  category  \
# 0  If I knew that my brother had committed a murd...            1.1   ingroup
# 1  When it comes to close friendships and romanti...            1.2   ingroup
# 2  Loyalty to oneâ€™s group is more important tha...            1.3   ingroup
# 3  The government should strive to improve the we...            1.4   ingroup
# 4  If a friend wanted to cut in with me on a long...            2.1  fairness
#
#    origin                      model  temperature  trial
# ...

# %% [markdown]
# #### drop "unknown" column

# %%
a = a.drop(["Unnamed: 0"], axis=1)
b = b.drop(["Unnamed: 0"], axis=1)

# %%
a.head()
# Out:
#                                             response  \
# 0  [TextBlock(citations=None, text='5', type='tex...
# 1  [TextBlock(citations=None, text='0', type='tex...
# 2  [TextBlock(citations=None, text='3', type='tex...
# 3  [TextBlock(citations=None, text='4', type='tex...
# 4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt  prompt_number  category  \
# 0  If I knew that my brother had committed a murd...            1.1   ingroup
# 1  When it comes to close friendships and romanti...            1.2   ingroup
# 2  Loyalty to oneâ€™s group is more important tha...            1.3   ingroup
# 3  The government should strive to improve the we...            1.4   ingroup
# 4  If a friend wanted to cut in with me on a long...            2.1  fairness
#
#    origin                      model  temperature  trial
# 0  graham  claude-3-5-haiku-20241022          0.5      1
# 1  graham  claude-3-5-haiku-20241022          0.5      1
# ...

# %% [markdown]
# #### sort out response

# %% [markdown]
# "[TextBlock(citations=None, text='5', type='text')]"

# %%
a['response_processed'] =  a['response'].apply(lambda x: re.sub('\D', '', str(x)))
a.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\llste\AppData\Local\Temp\ipykernel_18100\3110472496.py:1: SyntaxWarning: invalid escape sequence '\D'
#   a['response_processed'] =  a['response'].apply(lambda x: re.sub('\D', '', str(x)))
#                                             response  \
# 0  [TextBlock(citations=None, text='5', type='tex...
# 1  [TextBlock(citations=None, text='0', type='tex...
# 2  [TextBlock(citations=None, text='3', type='tex...
# 3  [TextBlock(citations=None, text='4', type='tex...
# 4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt  prompt_number  category  \
# 0  If I knew that my brother had committed a murd...            1.1   ingroup
# 1  When it comes to close friendships and romanti...            1.2   ingroup
# 2  Loyalty to oneâ€™s group is more important tha...            1.3   ingroup
# ...

# %%
b['response_processed'] =  b['response'].apply(lambda x: re.sub('\D', '', str(x)))
b.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\llste\AppData\Local\Temp\ipykernel_18100\4213628877.py:1: SyntaxWarning: invalid escape sequence '\D'
#   b['response_processed'] =  b['response'].apply(lambda x: re.sub('\D', '', str(x)))
#                                             response  \
# 0  [TextBlock(citations=None, text='4', type='tex...
# 1  [TextBlock(citations=None, text='0', type='tex...
# 2  [TextBlock(citations=None, text='4', type='tex...
# 3  [TextBlock(citations=None, text='4', type='tex...
# 4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt  prompt_number  category  \
# 0  If I knew that my brother had committed a murd...            1.1   ingroup
# 1  When it comes to close friendships and romanti...            1.2   ingroup
# 2  Loyalty to oneâ€™s group is more important tha...            1.3   ingroup
# ...

# %%
c['response_processed'] =  c['response'].apply(lambda x: re.sub('\D', '', str(x)))
c.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\llste\AppData\Local\Temp\ipykernel_18100\2024510123.py:1: SyntaxWarning: invalid escape sequence '\D'
#   c['response_processed'] =  c['response'].apply(lambda x: re.sub('\D', '', str(x)))
#    Unnamed: 0                                           response  \
# 0           0  [TextBlock(citations=None, text='4', type='tex...
# 1           1  [TextBlock(citations=None, text='0', type='tex...
# 2           2  [TextBlock(citations=None, text='1', type='tex...
# 3           3  [TextBlock(citations=None, text='4', type='tex...
# 4           4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt alignment  prompt_number  \
# 0  If I knew that my brother had committed a murd...   liberal            1.1
# 1  When it comes to close friendships and romanti...   liberal            1.2
# ...

# %%
d['response_processed'] =  d['response'].apply(lambda x: re.sub('\D', '', str(x)))
d.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\llste\AppData\Local\Temp\ipykernel_18100\1380049361.py:1: SyntaxWarning: invalid escape sequence '\D'
#   d['response_processed'] =  d['response'].apply(lambda x: re.sub('\D', '', str(x)))
#    Unnamed: 0                                           response  \
# 0           0  [TextBlock(citations=None, text='4', type='tex...
# 1           1  [TextBlock(citations=None, text='0', type='tex...
# 2           2  [TextBlock(citations=None, text='1', type='tex...
# 3           3  [TextBlock(citations=None, text='4', type='tex...
# 4           4  [TextBlock(citations=None, text='4', type='tex...
#
#                                               prompt alignment  prompt_number  \
# 0  If I knew that my brother had committed a murd...   liberal            1.1
# 1  When it comes to close friendships and romanti...   liberal            1.2
# ...

# %%
# a.to_csv(f'claude_unaligned_temp1_results_all_RARE.csv', index = True)
# b.to_csv(f'claude_unaligned_temp0.5_results_all_RARE.csv', index = True)

c.to_csv(f'claude_base_temp1_results_all_RARE.csv', index = True)
d.to_csv(f'claude_base_temp0.5_results_all_RARE.csv', index = True)
